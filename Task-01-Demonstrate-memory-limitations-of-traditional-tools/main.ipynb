# %% [markdown]
# ## Activity 1 — Load and Inspect Data

# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
import time
# DATASET LINK: https://www.kaggle.com/datasets/elemento/nyc-yellow-taxi-trip-data?select=yellow_tripdata_2015-01.csv
start = time.time()
df = pd.read_csv("../dataset/nyc_taxi.csv")
end = time.time()

print("Rows:", len(df))
print("Time taken:", end - start)
print(df.head())
# Out:
# Rows: 12748986
# Time taken: 44.089669704437256
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %% [markdown]
# ### Observe:
# - loading time
# - RAM usage and
# - lag.
# ### Observations:

# %% [markdown]
# ## Activity 2 — Chunked Loading

# %%
chunksize = 100000

for chunk in pd.read_csv("../dataset/nyc_taxi.csv", chunksize=chunksize):
    print("Chunk size:", len(chunk))
# Out:
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# Chunk size: 100000
# ...

# %% [markdown]
# ##  Activity 3 — Aggregation + Memory Check

# %%
avg_fare = df["fare_amount"].mean()
top5 = df.nlargest(5, "fare_amount")

print("Average Fare:", avg_fare)
print(top5)
# Out:
# Average Fare: 11.90565942577708
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 12477051         1  2015-01-22 21:12:26   2015-01-22 21:20:36
# 1851068          2  2015-01-02 20:06:34   2015-01-02 20:23:33
# 1588313          2  2015-01-16 14:48:00   2015-01-16 14:48:00
# 3590037          2  2015-01-23 11:15:00   2015-01-23 11:15:00
# 11519477         2  2015-01-06 14:47:00   2015-01-06 14:47:00
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 12477051                1            1.7        -73.961533        40.770638
# 1851068                 1            0.4        -74.014336        40.711857
# 1588313                 1            0.0          0.000000         0.000000
# 3590037                 1            0.0          0.000000         0.000000
# 11519477                1            0.0          0.000000         0.000000
#
#           RateCodeID store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# ...
